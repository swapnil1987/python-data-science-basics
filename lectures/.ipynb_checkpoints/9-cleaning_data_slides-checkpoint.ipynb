# %% [markdown]
# # Cleaning Data
#
# ## Prerequisites
# - Intro to pandas
# - Boolean selection
# - Indexing
#
# ## Outcomes
# - Use string methods to clean data
# - Drop missing data
# - Apply cleaning methods to real datasets

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Why Clean Data?
#
# - A significant proportion of time in data projects is spent on **data cleaning**
# - Not performing the analysis itself
# - pandas provides powerful data cleaning tools

# %% [markdown]
# ## Sample Dataset

# %%
df = pd.DataFrame({
    "numbers": ["#23", "#24", "#18", "#14", "#12", "#10", "#35"],
    "nums": ["23", "24", "18", "14", np.nan, "XYZ", "35"],
    "colors": ["green", "red", "yellow", "orange", "purple", "blue", "pink"],
    "other_column": [0, 1, 0, 2, 1, 0, 2]
})
df

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   numbers       7 non-null      object
#  1   nums          6 non-null      object
#  2   colors        7 non-null      object
#  3   other_column  7 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 356.0+ bytes
# None

# %% [markdown]
# ## Problem: Computing Mean
#
# What happens if we try to compute the mean of `numbers`?

# %%
# This will raise an error!
df["numbers"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # This will raise an error!
# ----> 2 df["numbers"].mean()
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\AppData\Local\miniconda3\envs\lecture-datascience\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '#23#24#18#14#12#10#35' to numeric

# %% [markdown]
# **Error:** `TypeError: Could not convert #23#24... to numeric`
#
# The `#` symbol prevents conversion to numeric type!

# %% [markdown]
# ## String Methods: The Slow Way
#
# We could loop through rows (but this is slow)...

# %%
# %%time

# list(df.iterrows())

# Iterate over all rows
for row in df.iterrows():
    index_value, column_values = row
    clean_number = int(column_values["numbers"].replace("#", ""))
    df.at[index_value, "numbers_loop"] = clean_number

df
# Out:
# CPU times: total: 0 ns
# Wall time: 992 μs
#   numbers nums  colors  other_column  numbers_loop
# 0     #23   23   green             0          23.0
# 1     #24   24     red             1          24.0
# 2     #18   18  yellow             0          18.0
# 3     #14   14  orange             2          14.0
# 4     #12  NaN  purple             1          12.0
# 5     #10  XYZ    blue             0          10.0
# 6     #35   35    pink             2          35.0

# %% [markdown]
# ## String Methods: The Fast Way
#
# Use `.str` accessor to apply string methods to entire columns!

# %%
# %%time

# Much faster! 2-500x depending on DataFrame size
df["numbers_str"] = df["numbers"].str.replace("#", "")

df
# Out:
# CPU times: total: 0 ns
# Wall time: 922 μs
#   numbers nums  colors  other_column  numbers_loop numbers_str
# 0     #23   23   green             0          23.0          23
# 1     #24   24     red             1          24.0          24
# 2     #18   18  yellow             0          18.0          18
# 3     #14   14  orange             2          14.0          14
# 4     #12  NaN  purple             1          12.0          12
# 5     #10  XYZ    blue             0          10.0          10
# 6     #35   35    pink             2          35.0          35

# %% [markdown]
# **Key Point:** `.str` methods operate on entire columns at once (vectorized operations)

# %% [markdown]
# ## More String Methods

# %%
# Check if colors contain 'p'
df["colors"].str.contains("p")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# Name: colors, dtype: bool

# %%
# Capitalize colors
df["colors"].str.capitalize()
# Out:
# 0     Green
# 1       Red
# 2    Yellow
# 3    Orange
# 4    Purple
# 5      Blue
# 6      Pink
# Name: colors, dtype: object

# %% [markdown]
# ## Type Conversions
#
# After removing `#`, we still have strings!
#
# Use `pd.to_numeric()` to convert to numbers:

# %%
print(df.dtypes)

df["numbers_str"] = pd.to_numeric(df["numbers_str"])
df.dtypes
# Out:
# numbers             object
# nums                object
# colors              object
# other_column         int64
# numbers_loop       float64
# numbers_str          int64
# numbers_numeric      int64
# dtype: object
# numbers             object
# nums                object
# colors              object
# other_column         int64
# numbers_loop       float64
# numbers_str          int64
# numbers_numeric      int64
# dtype: object

# %% [markdown]
# ## Using astype()
#
# Convert to different data types:

# %%
# Convert to string
df["numbers_numeric"].astype(str)
# Out:
# 0    23
# 1    24
# 2    18
# 3    14
# 4    12
# 5    10
# 6    35
# Name: numbers_numeric, dtype: object

# %%
# Convert to float
df["numbers_numeric"].astype(float)
# Out:
# 0    23.0
# 1    24.0
# 2    18.0
# 3    14.0
# 4    12.0
# 5    10.0
# 6    35.0
# Name: numbers_numeric, dtype: float64

# %% [markdown]
# ## Missing Data
#
# Our dataset has missing values:

# %%
df
# Out:
#   numbers nums  colors  other_column  numbers_loop numbers_str  \
# 0     #23   23   green             0          23.0          23
# 1     #24   24     red             1          24.0          24
# 2     #18   18  yellow             0          18.0          18
# 3     #14   14  orange             2          14.0          14
# 4     #12  NaN  purple             1          12.0          12
# 5     #10  XYZ    blue             0          10.0          10
# 6     #35   35    pink             2          35.0          35
#
#    numbers_numeric
# 0               23
# 1               24
# 2               18
# 3               14
# 4               12
# 5               10
# 6               35

# %% [markdown]
# ## Detecting Missing Data
#
# Use `.isnull()` to find missing values:

# %%
df.isnull()
# Out:
#    numbers   nums  colors  other_column  numbers_loop  numbers_str  \
# 0    False  False   False         False         False        False
# 1    False  False   False         False         False        False
# 2    False  False   False         False         False        False
# 3    False  False   False         False         False        False
# 4    False   True   False         False         False        False
# 5    False  False   False         False         False        False
# 6    False  False   False         False         False        False
#
#    numbers_numeric
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# 5            False
# 6            False

# %% [markdown]
# ## Missing Data by Column/Row

# %%
# Any missing data in each column?
df.isnull().any(axis=0).any()
# Out:
# np.True_

# %%
# Any missing data in each row?
df.isnull().any(axis=1).any()
# Out:
# np.True_

# %% [markdown]
# ## Handling Missing Data
#
# Two main approaches:
#
# 1. **Exclusion:** Drop missing data (`.dropna()`)
# 2. **Imputation:** Fill in predicted values (`.fillna()`)

# %% [markdown]
# ## Drop Missing Data

# %%
# Drop all rows containing missing data
df.dropna()
# Out:
#   numbers nums  colors  other_column  numbers_loop  numbers_str  \
# 0     #23   23   green             0          23.0           23
# 1     #24   24     red             1          24.0           24
# 2     #18   18  yellow             0          18.0           18
# 3     #14   14  orange             2          14.0           14
# 5     #10  XYZ    blue             0          10.0           10
# 6     #35   35    pink             2          35.0           35
#
#    numbers_numeric
# 0               23
# 1               24
# 2               18
# 3               14
# 5               10
# 6               35

# %% [markdown]
# ## Fill Missing Data

# %%
# Fill with a specific value
df.fillna(value=100)
# Out:
#   numbers nums  colors  other_column  numbers_loop  numbers_str  \
# 0     #23   23   green             0          23.0           23
# 1     #24   24     red             1          24.0           24
# 2     #18   18  yellow             0          18.0           18
# 3     #14   14  orange             2          14.0           14
# 4     #12  100  purple             1          12.0           12
# 5     #10  XYZ    blue             0          10.0           10
# 6     #35   35    pink             2          35.0           35
#
#    numbers_numeric
# 0               23
# 1               24
# 2               18
# 3               14
# 4               12
# 5               10
# 6               35

# %% [markdown]
# ## Forward/Backward Fill

# %%
# Use next valid observation
df.bfill()
# Out:
#   numbers nums  colors  other_column  numbers_loop  numbers_str  \
# 0     #23   23   green             0          23.0           23
# 1     #24   24     red             1          24.0           24
# 2     #18   18  yellow             0          18.0           18
# 3     #14   14  orange             2          14.0           14
# 4     #12  XYZ  purple             1          12.0           12
# 5     #10  XYZ    blue             0          10.0           10
# 6     #35   35    pink             2          35.0           35
#
#    numbers_numeric
# 0               23
# 1               24
# 2               18
# 3               14
# 4               12
# 5               10
# 6               35

# %%
# Use previous valid observation
df.ffill()
# Out:
#   numbers nums  colors  other_column  numbers_loop  numbers_str  \
# 0     #23   23   green             0          23.0           23
# 1     #24   24     red             1          24.0           24
# 2     #18   18  yellow             0          18.0           18
# 3     #14   14  orange             2          14.0           14
# 4     #12   14  purple             1          12.0           12
# 5     #10  XYZ    blue             0          10.0           10
# 6     #35   35    pink             2          35.0           35
#
#    numbers_numeric
# 0               23
# 1               24
# 2               18
# 3               14
# 4               12
# 5               10
# 6               35

# %% [markdown]
# ## Case Study: Chipotle Orders
#
# Real data from NYTimes article about Chipotle orders
#
# - Nearly 2,000 orders
# - Information on items and prices

# %%
url = "https://datascience.quantecon.org/assets/data/chipotle_raw.csv.zip"
chipotle = pd.read_csv(url)
chipotle.head(10)

np.sum(chipotle['item_name'].str.contains("Chicken"))
# Out:
# np.int64(0)

# %% [markdown]
# ## Exercise: Chipotle Analysis
#
# Use this data to answer:
#
# 1. What is the average price of an item with chicken?
# 2. What is the average price of an item with steak?
# 3. Did chicken or steak produce more revenue (total)?
# 4. How many missing items are in this dataset?
#
# **Hint:** You'll need to clean the `item_price` column first!

# %% [markdown]
# ## Performance Comparison
#
# Let's compare loop vs `.str` methods on larger data:

# %%
test = pd.DataFrame({"floats": np.round(100*np.random.rand(100000), 2)})
test["strings"] = test["floats"].astype(str) + "%"
test.head()
# Out:
#    floats strings
# 0   38.44  38.44%
# 1   10.30   10.3%
# 2   72.40   72.4%
# 3   10.86  10.86%
# 4   65.10   65.1%

# %% [markdown]
# ## Loop Method (Slow)

# %%
# %%time

for row in test.iterrows():
    index_value, column_values = row
    clean_number = column_values["strings"].replace("%", "")
    test.at[index_value, "numbers_loop"] = clean_number
# Out:
# CPU times: total: 2.33 s
# Wall time: 7.7 s

# %% [markdown]
# ## String Method (Fast)

# %%
# %%time
test["numbers_str_method"] = test["strings"].str.replace("%", "")
# Out:
# CPU times: total: 0 ns
# Wall time: 19.9 ms

# %%
# Verify they're the same
test["numbers_str_method"].equals(test["numbers_loop"])
# Out:
# True

# %% [markdown]
# ## Key Takeaways
#
# 1. Use `.str` accessor for vectorized string operations
# 2. Use `pd.to_numeric()` and `.astype()` for type conversions
# 3. Handle missing data with `.dropna()` or `.fillna()`
# 4. Clean data before analysis!
# 5. Vectorized operations are much faster than loops

# %% [markdown]
# ## Practice Exercises
#
# **Exercise 1:** Convert `"#39"` to a number
#
# **Exercise 2:** Create `colors_upper` column with uppercase colors
#
# **Exercise 3:** Convert `nums` column to numeric (handle errors!)
#
# **Exercise 4:** Analyze the Chipotle dataset
